# %%
import matplotlib.pyplot as plt
import numpy as np

# Data provided by the user
data = [
    15.885, 15.96, 16.12, 16.24, 16.25, 16.265, 16.325, 16.36, 16.365, 16.37,
    16.37, 16.375, 16.42, 16.445, 16.475, 16.495, 16.51, 16.515, 16.535, 16.555,
    16.565, 16.605, 16.74, 16.765, 16.805, 16.815, 16.82, 16.825, 16.83, 16.85,
    16.86, 16.875, 16.885, 16.89, 16.9, 16.91, 16.91, 16.93, 16.95, 16.955,
    16.96, 16.99, 17, 17.01, 17.025, 17.05, 17.06, 17.065, 17.075, 17.085,
    17.09, 17.105, 17.11, 17.12, 17.125, 17.135, 17.135, 17.15, 17.155, 17.155,
    17.155, 17.18, 17.185, 17.21, 17.215, 17.23, 17.245, 17.245, 17.245, 17.255,
    17.255, 17.26, 17.26, 17.27, 17.275, 17.29, 17.315, 17.315, 17.315, 17.325,
    17.325, 17.34, 17.34, 17.345, 17.35, 17.355, 17.36, 17.36, 17.365, 17.37,
    17.38, 17.385, 17.385, 17.4, 17.405, 17.405, 17.405, 17.41, 17.42, 17.435,
    17.44, 17.44, 17.44, 17.44, 17.445, 17.45, 17.455, 17.465, 17.465, 17.485,
    17.515, 17.525, 17.545, 17.575, 17.58, 17.6, 17.6, 17.605, 17.61, 17.615,
    17.62, 17.62, 17.625, 17.63, 17.635, 17.64, 17.655, 17.66, 17.66, 17.68,
    17.7, 17.72, 17.73, 17.73, 17.745, 17.76, 17.765, 17.77, 17.775, 17.8,
    17.805, 17.81, 17.82, 17.825, 17.825, 17.83, 17.875, 17.885, 17.885, 17.93,
    17.985, 17.99, 18.02, 18.025, 18.045, 18.055, 18.06, 18.07, 18.1, 18.18,
    18.21, 18.21, 18.215, 18.25, 18.285, 18.31, 18.315, 18.32, 18.345, 18.35,
    18.37, 18.4, 18.425, 18.46, 18.465, 18.47, 18.475, 18.485, 18.5, 18.505,
    18.52, 18.535, 18.56, 18.565, 18.585, 18.605, 18.62, 18.655, 18.655, 18.665,
    18.67, 18.67, 18.675, 18.675, 18.68, 18.68, 18.7, 18.76, 18.78, 18.785,
    18.795, 18.8, 18.8, 18.8, 18.805, 18.825, 18.83, 18.83, 18.855, 18.875,
    18.875, 18.88, 18.895, 18.895, 18.895, 18.895, 18.895, 18.9, 18.9, 18.91,
    18.91, 18.915, 18.915, 18.915, 18.92, 18.92, 18.925, 18.925, 18.93, 18.94,
    18.94, 18.94, 18.95, 18.95, 18.95, 18.96, 18.97, 18.97, 18.97, 18.975,
    18.975, 18.975, 18.98, 18.98, 18.98, 18.98, 18.985, 18.985, 18.985, 18.985,
    18.99, 18.99, 18.99, 18.995, 18.995, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19,
    19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19, 19
]

# Define the sections
low_section = (0, 150)
mid_section = (150, 250)
top_section = (250, len(data))

# Create the plot
plt.figure(figsize=(12, 3))
x = np.arange(len(data))
y = np.array(data)

# Fill each section with corresponding colors
plt.bar(x[:low_section[1]], y[:low_section[1]], color="red", alpha=0.3)
plt.bar(x[low_section[1]:mid_section[1]], y[low_section[1]:mid_section[1]], color="orange", alpha=0.3,)
plt.bar(x[mid_section[1]:], y[mid_section[1]:], color="green", alpha=0.3)

# Plot each section with distinct colors
plt.plot(x[:low_section[1]], y[:low_section[1]], color="red", label="Bottom section")
plt.plot(x[low_section[1]:mid_section[1]], y[low_section[1]:mid_section[1]], color="orange", label="Middle sectio")
plt.plot(x[mid_section[1]:], y[mid_section[1]:], color="green", label="Top section")

# Add vertical lines to divide the sections
plt.axvline(x=low_section[1], color="black", linestyle="--", label="Section Divider")
plt.axvline(x=mid_section[1], color="black", linestyle="--")

# Customize the plot
plt.title("Stair Wear Depth")
plt.xlabel("Stair Number")
plt.ylabel("Wear Depth(cm)")
plt.ylim(15, 20)  # Adjust y-axis range
plt.legend()
plt.grid(False)  # Remove grid lines

# Show the plot
plt.show()
